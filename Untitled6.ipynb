# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Change this to your Drive folder location
WORKING_DIRECTORY = '/content/drive/MyDrive/blurFacesRealTime'

os.chdir(WORKING_DIRECTORY)

# %%
# !ls
# Out:
# bbx1.jpg  example.mp4  group.jpg			main.py
# bbx.jpg   girl.jpg     haarcascade_frontalface_alt.xml	night.jpg

# %%
import cv2
import numpy as np
def resize(img,new_width=500):
    height,width,_ = img.shape
    ratio = height/width
    new_height = int(ratio*new_width)
    return cv2.resize(img,(new_width,new_height))

face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")

# %%
img = cv2.imread("night.jpg")

# %%
detections = face_cascade.detectMultiScale(img,scaleFactor=1.1,minNeighbors = 1)

# %%
print(detections)
# Out:
# [[212 208  52  52]
#  [183 259  52  52]
#  [494 284  65  65]
#  [554 243  88  88]
#  [442 571  38  38]]

# %%
for face in detections:
  x,y,w,h = face
  img[y:y+h,x:x+w] = cv2.GaussianBlur(img[y:y+h,x:x+w],(15,15),cv2.BORDER_DEFAULT)
  #cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

# %%
cv2.imwrite('nig.jpg', img)
# Out:
# True
